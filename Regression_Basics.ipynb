# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("diamond.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  carat colour clarity certification  price
# 0           1   0.30      D     VS2           GIA   1302
# 1           2   0.30      E     VS1           GIA   1510
# 2           3   0.30      G    VVS1           GIA   1510
# 3           4   0.30      G     VS1           GIA   1260
# 4           5   0.31      D     VS1           GIA   1641
# 5           6   0.31      E     VS1           GIA   1555
# 6           7   0.31      F     VS1           GIA   1427
# 7           8   0.31      G    VVS2           GIA   1427
# 8           9   0.31      H     VS2           GIA   1126
# 9          10   0.31      I     VS1           GIA   1126

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  carat colour clarity certification  price
# 0             1   0.30      D     VS2           GIA   1302
# 1             2   0.30      E     VS1           GIA   1510
# 2             3   0.30      G    VVS1           GIA   1510
# 3             4   0.30      G     VS1           GIA   1260
# 4             5   0.31      D     VS1           GIA   1641
# ..          ...    ...    ...     ...           ...    ...
# 303         304   1.01      I     VS1           HRD   8175
# 304         305   1.02      F    VVS2           HRD  10796
# 305         306   1.06      H    VVS2           HRD   9890
# 306         307   1.02      H     VS2           HRD   8959
# 307         308   1.09      I    VVS2           HRD   9107
#
# [308 rows x 6 columns]>

# %%
df.shape
# Out:
# (308, 6)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# carat            0
# colour           0
# clarity          0
# certification    0
# price            0
# dtype: int64

# %%
df[["carat","price"]]
# Out:
#      carat  price
# 0     0.30   1302
# 1     0.30   1510
# 2     0.30   1510
# 3     0.30   1260
# 4     0.31   1641
# ..     ...    ...
# 303   1.01   8175
# 304   1.02  10796
# 305   1.06   9890
# 306   1.02   8959
# 307   1.09   9107
#
# [308 rows x 2 columns]

# %%
x = df[["carat"]]
y = df["price"]

# %%
plt.scatter(x,y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y ,test_size = 0.30)

# %%
x_train
# Out:
#      carat
# 10    0.32
# 106   0.75
# 264   0.80
# 80    0.50
# 190   0.29
# ..     ...
# 81    0.50
# 249   0.66
# 92    0.70
# 243   0.60
# 15    0.34
#
# [215 rows x 1 columns]

# %%
y_train
# Out:
# 10     1468
# 106    7368
# 264    6416
# 80     3501
# 190    1238
#        ...
# 81     3432
# 249    4300
# 92     5122
# 243    3421
# 15     1551
# Name: price, Length: 215, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.884925361426659

# %%
plt.scatter(x_test,y_test,color = "black",label = "Actual")
plt.plot(x_test,y_pred, color = "red", label = "Predicted")
plt.legend()
plt.grid(True)

# %%
model.predict([[0.31]])
# Out:
# C:\Users\PAPA DICKSON\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1247.47396256])
